# %% [markdown]
# ## Visualizing relationships in Data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# ### 1. Numerical Data Ploting
# - replot()
# - scatterplot()
# - lineplot()

# %%
sns.set(style='darkgrid')

# %%
# getting available dataset names in Seaborn library
print(sb.get_dataset_names())
# Out:
# C:\Users\Sony\anaconda3\lib\site-packages\seaborn\utils.py:384: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\Sony\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
data=sb.load_dataset('tips')
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sb.relplot(x='total_bill', y='tip', data=data)

# %%
data['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
data['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sb.relplot(x='total_bill',y='tip',data=data,hue='sex',style='smoker')

# %%
color_palette=sb.cubehelix_palette(light=0.7,n_colors=6)

# %%
sb.relplot(x='total_bill',y='tip',data=data,hue='size',palette=color_palette)

# %%
sb.relplot(x='total_bill',y='tip',data=data,size='size',sizes=(15,150))

# %%
sb.relplot(x='total_bill',y='tip',hue='sex',col='time',data=data)

# %%
sb.relplot(x='total_bill',y='tip',hue='sex',col='size',data=data)

# %%
sb.relplot(x='total_bill',y='tip',hue='sex',col='size',height=3,col_wrap=3,data=data)

# %%
## Lineplot()

# %%
sb.lineplot(x='total_bill',y='tip',data=data)

# %%
## scatterplot()

# %%
sb.scatterplot(x='total_bill',y='tip',data=data,hue='sex',size='size',style='time')

# %%
fmri=sb.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sb.relplot(x='timepoint',y='signal',kind='line',data=fmri,ci='sd')

# %%
sb.relplot(x='timepoint',y='signal',hue='event',kind='line',data=fmri,ci=False,)

# %%
sb.relplot(x='timepoint',y='signal',hue='event',style='region',markers=True,dashes=False,kind='line',data=fmri)

# %%
sb.relplot(x='timepoint',y='signal',hue='event',style='region',kind='line',data=fmri)

# %%
sb.relplot(x='timepoint',y='signal',hue='subject',row='event',col='region',kind='line',height=3,data=fmri)

# %%
## lineplot()

# %%
sns.lineplot(x='timepoint',y='signal',hue='region',style='event',markers=True,ci=70,data=fmri,err_style='bars')

# %%
sb.lineplot(x='timepoint',y='signal',hue='region',units='subject',estimator=None,data=fmri.query("event=='stim'"))

# %%
sacc=sns.load_dataset('dots').query("align=='sacc'")
sacc.head()
# Out:
#     align choice  time  coherence  firing_rate
# 394  sacc     T1  -600        0.0    45.232512
# 395  sacc     T1  -580        0.0    45.426403
# 396  sacc     T1  -560        0.0    43.071647
# 397  sacc     T1  -560        3.2    44.633471
# 398  sacc     T1  -540        0.0    45.479431

# %%
sb.relplot(x='time',y='firing_rate',data=sacc,kind='line',hue='coherence')

# %%
sb.relplot(x='time',y='firing_rate',hue='coherence',size='choice',style='choice',kind='line',data=sacc)

# %%
##lineplot()

# %%
sns.lineplot(x='time',y='firing_rate',hue='coherence',style='choice',data=sacc)

# %%
dates_of_days=pd.date_range('today',periods=250) # dates range 
values=np.random.randn(250).cumsum()
values
df=pd.DataFrame(dict(time=dates_of_days,value=values))
df.head()
# Out:
#                         time     value
# 0 2020-07-24 20:57:14.976010  1.079285
# 1 2020-07-25 20:57:14.976010  1.435011
# 2 2020-07-26 20:57:14.976010  2.500690
# 3 2020-07-27 20:57:14.976010  1.564760
# 4 2020-07-28 20:57:14.976010 -1.264744

# %%
plot=sns.relplot(x='time',y='value',kind='line',data=df)
plot.fig.autofmt_xdate()

# %% [markdown]
# ### 2.Categorical Data Ploting
# - catplot()
# - boxplot()
# - stripplot()
# - swarmplot()
# -
# -

# %%
#### catplot()

# %%
sb.catplot(x='day',y='total_bill',data=data,jitter=False)

# %%
#To overcome overlapping the data
sns.catplot(x='day',y='total_bill',data=data,kind='swarm',hue='sex')

# %%
sns.catplot(x='smoker',y='tip',data=data,order=['No','Yes'])

# %%
sns.catplot(x='day',y='total_bill',data=data,kind='bar')

# %%
sns.catplot(x='day',y='total_bill',data=data,hue='time',kind='box')

# %%
sns.catplot(x='day',y='total_bill',data=data,hue='sex',kind='box',dodge=False)

# %%
sns.catplot(x='day',y='total_bill',data=data,hue='time',kind='boxen')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(y='total_bill',x='size',data=data,kind='bar')

# %%
sns.catplot(x='day',y='total_bill',hue='time',kind='violin',data=data,split=True)

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sb.catplot(x='sex',y='survived',hue='class',kind='bar',data=titanic)

# %%
sb.catplot(x='deck',kind='count',palette='ch:0.65',data=titanic,hue='class')

# %%
sb.catplot(x='sex',y='survived',hue='class',kind='point',data=titanic)

# %% [markdown]
# ### 3.Visualizing Distribution of the Data
# - distplot()
# - kdeplot()
# - jointplot()
# - rugplot()

# %%
x=np.random.randn(100)
sns.distplot(x)

# %%
sns.distplot(x,kde=False)

# %%
sb.distplot(x,kde=True,hist=False,rug=True,bins=25)

# %%
sb.kdeplot(x,shade=True)

# %%
sb.kdeplot(x,shade=True,bw=1,cut=0)

# %%
sns.jointplot(x='total_bill',y='tip',data=data)

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='kde')

# %%
sns.pairplot(data)

# %% [markdown]
# ### 4.Relationships through Linear Regression
# - regplot()
# - lmplot()

# %%
sb.regplot(x='total_bill',y='tip',data=data)

# %%
sb.lmplot(x='total_bill',y='tip',data=data)
